# %%
# imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %% [markdown]
# Data EDA for 60FR_100W_90A_0B

# %% [markdown]
# data ingestion

# %%
import chardet

# Detect the encoding
with open("../data/PHP_E_60FR_100W_90A_0B.csv", "rb") as file:
    result = chardet.detect(file.read())
    print(result['encoding'])
# Out:
# UTF-16

# %%
# loading raw data
# experiment 60FR 100W DI Water
# DATE: 21 3 2024

# loading thermal data
df_raw_60FR_100W_Therm = pd.read_csv("../data/PHP_T_60FR_100W_90A_0B.csv", encoding='UTF_16',delimiter='\t')

# loading electrical data
df_raw_60FR_100W_Elect = pd.read_csv("../data/PHP_E_60FR_100W_90A_0B.csv", encoding='UTF_16',delimiter='\t')

# %%
display(df_raw_60FR_100W_Therm)
# Out:
#            TIME        DATE  TC-1  TC-2  TC-3  TC-4  TC-5  TC-6  TC-7  TC-8  \
# 0           NaN  22/02/2024  36.5  36.2  35.5  35.3  34.7  29.3  29.0  29.0
# 1      15:57:39  22/02/2024  36.5  36.8  36.0  35.8  35.4  29.3  29.0  29.0
# 2      15:57:40  22/02/2024  36.5  36.8  36.0  35.8  35.4  29.4  28.9  29.0
# 3      15:57:42  22/02/2024  36.5  36.8  36.0  35.8  35.4  29.4  28.9  29.0
# 4      15:57:45  22/02/2024  36.5  36.8  36.0  35.8  35.4  29.4  28.9  29.0
# ...         ...         ...   ...   ...   ...   ...   ...   ...   ...   ...
# 13715  18:23:41  21/03/2024  96.0  95.4  95.7  97.3  95.5  78.6  90.8  81.5
# 13716  18:23:42  21/03/2024  95.6  95.2  94.9  96.3  95.5  78.6  90.8  81.5
# 13717  18:23:43  21/03/2024  95.6  95.2  94.9  96.3  86.7  78.7  89.6  82.9
# 13718  18:23:45  21/03/2024  95.6  95.2  94.9  96.3  86.7  78.7  89.6  82.9
# 13719  18:23:48  21/03/2024  95.6  95.2  94.9  96.3  86.7  78.7  89.6  82.9
#
#         TC-9  PRESSURE  HEATER  HEATER SET POINT  Unnamed: 14
# 0       26.5     -0.69      47               170          NaN
# 1       26.5     -0.69      47               170          NaN
# 2       26.5     -0.69      47               170          NaN
# 3       26.5     -0.68      48               170          NaN
# 4       26.5     -0.68      48               170          NaN
# ...      ...       ...     ...               ...          ...
# 13715  103.7      0.83     134               170          NaN
# 13716  103.7      0.83     134               170          NaN
# 13717  103.7      0.83     134               170          NaN
# 13718  102.4      0.72     134               170          NaN
# 13719  102.4      0.72     134               170          NaN
#
# [13720 rows x 15 columns]

# %%
display(df_raw_60FR_100W_Elect)
# Out:
#            TIME        DATE  voltage  current  power  Unnamed: 5
# 0           NaN  22/02/2024     82.1    1.216  100.2         NaN
# 1      15:57:38  22/02/2024     82.1    1.216  100.2         NaN
# 2      15:57:40  22/02/2024     82.1    1.216  100.0         NaN
# 3      15:57:42  22/02/2024     82.1    1.216  100.0         NaN
# 4      15:57:44  22/02/2024     82.1    1.216   99.9         NaN
# ...         ...         ...      ...      ...    ...         ...
# 13716  18:23:41  21/03/2024     84.1    1.235  104.0         NaN
# 13717  18:23:43  21/03/2024     84.1    1.234  104.0         NaN
# 13718  18:23:44  21/03/2024     84.1    1.235  104.0         NaN
# 13719  18:23:48  21/03/2024     84.0    1.234  103.8         NaN
# 13720  18:23:52  21/03/2024     84.1    1.235  103.9         NaN
#
# [13721 rows x 6 columns]

# %%
df_raw_60FR_100W_Therm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13720 entries, 0 to 13719
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   TIME              13719 non-null  object
#  1   DATE              13720 non-null  object
#  2   TC-1              13720 non-null  float64
#  3   TC-2              13720 non-null  float64
#  4   TC-3              13720 non-null  float64
#  5   TC-4              13720 non-null  float64
#  6   TC-5              13720 non-null  float64
#  7   TC-6              13720 non-null  float64
#  8   TC-7              13720 non-null  float64
#  9   TC-8              13720 non-null  float64
#  10  TC-9              13720 non-null  float64
#  11  PRESSURE          13720 non-null  float64
#  12  HEATER            13720 non-null  int64
#  13  HEATER SET POINT  13720 non-null  int64
#  14  Unnamed: 14       0 non-null      float64
# dtypes: float64(11), int64(2), object(2)
# memory usage: 1.6+ MB

# %%
def process_datetime(df:pd.DataFrame, col:str='date')->pd.DataFrame:
    df[col] = df['DATE'] + df['TIME']
    df[col] = pd.to_datetime(df[col], format='%d/%m/%Y%H:%M:%S')
    return df

# %%
df_raw_60FR_100W_Elect = process_datetime(df_raw_60FR_100W_Elect)
df_raw_60FR_100W_Therm = process_datetime(df_raw_60FR_100W_Therm)

# %%
def join_thermal_electrical_data(df_thermal:pd.DataFrame, df_electrical:pd.DataFrame)->pd.DataFrame:
    df_join = pd.merge(left=df_thermal, right=df_electrical, on=['date', 'TIME', 'DATE'])
    df_join.dropna(axis=1, how='all', inplace=True)
    df_join.dropna(axis=0, how='any', inplace=True)
    df_join.rename(columns=lambda x: x.replace('-', '_'), inplace=True)
    return df_join

# %%
df_raw_60FR_100W = join_thermal_electrical_data(df_thermal=df_raw_60FR_100W_Therm,
                                                df_electrical=df_raw_60FR_100W_Elect)

# %%
display(df_raw_60FR_100W)
# Out:
#            TIME        DATE  TC_1  TC_2  TC_3  TC_4  TC_5  TC_6  TC_7  TC_8  \
# 1      15:57:40  22/02/2024  36.5  36.8  36.0  35.8  35.4  29.4  28.9  29.0
# 2      15:57:42  22/02/2024  36.5  36.8  36.0  35.8  35.4  29.4  28.9  29.0
# 3      15:57:49  22/02/2024  36.5  36.8  36.0  35.8  35.4  29.4  28.9  29.0
# 4      15:57:49  22/02/2024  36.5  36.8  36.0  35.8  35.4  29.4  28.9  29.0
# 5      15:57:55  22/02/2024  37.3  37.5  36.8  36.6  36.1  29.3  28.9  29.0
# ...         ...         ...   ...   ...   ...   ...   ...   ...   ...   ...
# 10649  18:23:36  21/03/2024  96.0  95.4  95.7  97.3  95.5  78.6  90.8  81.5
# 10650  18:23:41  21/03/2024  96.0  95.4  95.7  97.3  95.5  78.6  90.8  81.5
# 10651  18:23:41  21/03/2024  96.0  95.4  95.7  97.3  95.5  78.6  90.8  81.5
# 10652  18:23:43  21/03/2024  95.6  95.2  94.9  96.3  86.7  78.7  89.6  82.9
# 10653  18:23:48  21/03/2024  95.6  95.2  94.9  96.3  86.7  78.7  89.6  82.9
#
#         TC_9  PRESSURE  HEATER  HEATER SET POINT                date  voltage  \
# 1       26.5     -0.69      47               170 2024-02-22 15:57:40     82.1
# 2       26.5     -0.68      48               170 2024-02-22 15:57:42     82.1
# 3       26.5     -0.68      48               170 2024-02-22 15:57:49     82.1
# 4       26.5     -0.68      48               170 2024-02-22 15:57:49     82.1
# 5       26.5     -0.68      49               170 2024-02-22 15:57:55     82.1
# ...      ...       ...     ...               ...                 ...      ...
# 10649  103.7      0.83     134               170 2024-03-21 18:23:36     84.1
# 10650  103.7      0.83     134               170 2024-03-21 18:23:41     84.1
# 10651  103.7      0.83     134               170 2024-03-21 18:23:41     84.1
# 10652  103.7      0.83     134               170 2024-03-21 18:23:43     84.1
# 10653  102.4      0.72     134               170 2024-03-21 18:23:48     84.0
#
#        current  power
# 1        1.216  100.0
# 2        1.216  100.0
# 3        1.216   99.9
# 4        1.215   99.7
# 5        1.215   99.8
# ...        ...    ...
# 10649    1.235  104.0
# 10650    1.235  104.0
# 10651    1.235  104.0
# 10652    1.234  104.0
# 10653    1.234  103.8
#
# [10653 rows x 18 columns]

# %%
df_raw_60FR_100W.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10653 entries, 1 to 10653
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   TIME              10653 non-null  object
#  1   DATE              10653 non-null  object
#  2   TC_1              10653 non-null  float64
#  3   TC_2              10653 non-null  float64
#  4   TC_3              10653 non-null  float64
#  5   TC_4              10653 non-null  float64
#  6   TC_5              10653 non-null  float64
#  7   TC_6              10653 non-null  float64
#  8   TC_7              10653 non-null  float64
#  9   TC_8              10653 non-null  float64
#  10  TC_9              10653 non-null  float64
#  11  PRESSURE          10653 non-null  float64
#  12  HEATER            10653 non-null  int64
#  13  HEATER SET POINT  10653 non-null  int64
#  14  date              10653 non-null  datetime64[ns]
#  15  voltage           10653 non-null  float64
#  16  current           10653 non-null  float64
#  17  power             10653 non-null  float64
# dtypes: datetime64[ns](1), float64(13), int64(2), object(2)
# memory usage: 1.5+ MB

# %%
df_raw_60FR_100W.set_index('date')
# Out:
#                          TIME        DATE  TC_1  TC_2  TC_3  TC_4  TC_5  TC_6  \
# date
# 2024-02-22 15:57:40  15:57:40  22/02/2024  36.5  36.8  36.0  35.8  35.4  29.4
# 2024-02-22 15:57:42  15:57:42  22/02/2024  36.5  36.8  36.0  35.8  35.4  29.4
# 2024-02-22 15:57:49  15:57:49  22/02/2024  36.5  36.8  36.0  35.8  35.4  29.4
# 2024-02-22 15:57:49  15:57:49  22/02/2024  36.5  36.8  36.0  35.8  35.4  29.4
# 2024-02-22 15:57:55  15:57:55  22/02/2024  37.3  37.5  36.8  36.6  36.1  29.3
# ...                       ...         ...   ...   ...   ...   ...   ...   ...
# 2024-03-21 18:23:36  18:23:36  21/03/2024  96.0  95.4  95.7  97.3  95.5  78.6
# 2024-03-21 18:23:41  18:23:41  21/03/2024  96.0  95.4  95.7  97.3  95.5  78.6
# 2024-03-21 18:23:41  18:23:41  21/03/2024  96.0  95.4  95.7  97.3  95.5  78.6
# 2024-03-21 18:23:43  18:23:43  21/03/2024  95.6  95.2  94.9  96.3  86.7  78.7
# 2024-03-21 18:23:48  18:23:48  21/03/2024  95.6  95.2  94.9  96.3  86.7  78.7
#
#                      TC_7  TC_8   TC_9  PRESSURE  HEATER  HEATER SET POINT  \
# date
# 2024-02-22 15:57:40  28.9  29.0   26.5     -0.69      47               170
# 2024-02-22 15:57:42  28.9  29.0   26.5     -0.68      48               170
# 2024-02-22 15:57:49  28.9  29.0   26.5     -0.68      48               170
# 2024-02-22 15:57:49  28.9  29.0   26.5     -0.68      48               170
# 2024-02-22 15:57:55  28.9  29.0   26.5     -0.68      49               170
# ...                   ...   ...    ...       ...     ...               ...
# 2024-03-21 18:23:36  90.8  81.5  103.7      0.83     134               170
# 2024-03-21 18:23:41  90.8  81.5  103.7      0.83     134               170
# 2024-03-21 18:23:41  90.8  81.5  103.7      0.83     134               170
# 2024-03-21 18:23:43  89.6  82.9  103.7      0.83     134               170
# 2024-03-21 18:23:48  89.6  82.9  102.4      0.72     134               170
#
#                      voltage  current  power
# date
# 2024-02-22 15:57:40     82.1    1.216  100.0
# 2024-02-22 15:57:42     82.1    1.216  100.0
# 2024-02-22 15:57:49     82.1    1.216   99.9
# 2024-02-22 15:57:49     82.1    1.215   99.7
# 2024-02-22 15:57:55     82.1    1.215   99.8
# ...                      ...      ...    ...
# 2024-03-21 18:23:36     84.1    1.235  104.0
# 2024-03-21 18:23:41     84.1    1.235  104.0
# 2024-03-21 18:23:41     84.1    1.235  104.0
# 2024-03-21 18:23:43     84.1    1.234  104.0
# 2024-03-21 18:23:48     84.0    1.234  103.8
#
# [10653 rows x 17 columns]

# %%
df_raw_60FR_100W.columns.to_list()
# Out:
# ['TIME',
#  'DATE',
#  'TC_1',
#  'TC_2',
#  'TC_3',
#  'TC_4',
#  'TC_5',
#  'TC_6',
#  'TC_7',
#  'TC_8',
#  'TC_9',
#  'PRESSURE',
#  'HEATER',
#  'HEATER SET POINT',
#  'date',
#  'voltage',
#  'current',
#  'power']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(18, 6))
plt.plot(df_raw_60FR_100W[['TC_1', 'TC_2', 'TC_3', 'TC_4', 'TC_5']], label=f'Evaporator T[C]')
plt.xlabel('date')
plt.ylabel('Tc1')
plt.xlim(0,2600)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(18, 9))
for tc in df_raw_60FR_100W.columns.to_list():
    if tc.startswith("TC_"):
        if tc.split('_')[1] in ['6', '7', '8', '9']:
            e = 'Condenser'
            c = 'b'
        else:
            e = 'Evaporator'
            c = 'r'
        plt.plot(df_raw_60FR_100W[tc], label=f'{e}_T[C]_{tc}')
plt.xlabel('date')
plt.ylabel('Tc1')
# plt.xlim(0,2600)
plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(18, 6))
plt.plot(df_raw_60FR_100W[['TC_6','TC_7','TC_8', 'TC_9']], label='Condenser T[C]')
plt.xlabel('date')
plt.ylabel('Tc1')
# plt.xlim(0,2600)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(18, 6))
plt.plot(df_raw_60FR_100W['power'] ,df_raw_60FR_100W[['TC_1', 'TC_2', 'TC_3', 'TC_4', 'TC_5']], label='Evaporator T[C]')
plt.xlabel('date')
plt.ylabel('Tc1')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(18, 6))
plt.plot(df_raw_60FR_100W['power'])
plt.xlabel('date')
plt.ylabel('Tc1')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
df_raw_60FR_100W['Te_mean'] = df_raw_60FR_100W[['TC_1', 'TC_2', 'TC_3', 'TC_4', 'TC_5']].mean(axis=1)
df_raw_60FR_100W['Tc_mean'] = df_raw_60FR_100W[['TC_6','TC_7','TC_8', 'TC_9']].mean(axis=1)
df_raw_60FR_100W['Te_std'] = df_raw_60FR_100W[['TC_1', 'TC_2', 'TC_3', 'TC_4', 'TC_5']].std(axis=1)
df_raw_60FR_100W['Tc_std'] = df_raw_60FR_100W[['TC_6','TC_7','TC_8', 'TC_9']].std(axis=1)
df_raw_60FR_100W.head()
# Out:
#        TIME        DATE  TC_1  TC_2  TC_3  TC_4  TC_5  TC_6  TC_7  TC_8  ...  \
# 1  15:57:40  22/02/2024  36.5  36.8  36.0  35.8  35.4  29.4  28.9  29.0  ...
# 2  15:57:42  22/02/2024  36.5  36.8  36.0  35.8  35.4  29.4  28.9  29.0  ...
# 3  15:57:49  22/02/2024  36.5  36.8  36.0  35.8  35.4  29.4  28.9  29.0  ...
# 4  15:57:49  22/02/2024  36.5  36.8  36.0  35.8  35.4  29.4  28.9  29.0  ...
# 5  15:57:55  22/02/2024  37.3  37.5  36.8  36.6  36.1  29.3  28.9  29.0  ...
#
#    HEATER  HEATER SET POINT                date  voltage current  power  \
# 1      47               170 2024-02-22 15:57:40     82.1   1.216  100.0
# 2      48               170 2024-02-22 15:57:42     82.1   1.216  100.0
# 3      48               170 2024-02-22 15:57:49     82.1   1.216   99.9
# 4      48               170 2024-02-22 15:57:49     82.1   1.215   99.7
# 5      49               170 2024-02-22 15:57:55     82.1   1.215   99.8
#
#    Te_mean  Tc_mean    Te_std    Tc_std
# 1    36.10   28.450  0.556776  1.317826
# 2    36.10   28.450  0.556776  1.317826
# 3    36.10   28.450  0.556776  1.317826
# 4    36.10   28.450  0.556776  1.317826
# 5    36.86   28.425  0.559464  1.294540
#
# [5 rows x 22 columns]

# %%
df_raw_60FR_100W.reset_index()
# Out:
#        index      TIME        DATE  TC_1  TC_2  TC_3  TC_4  TC_5  TC_6  TC_7  \
# 0          1  15:57:40  22/02/2024  36.5  36.8  36.0  35.8  35.4  29.4  28.9
# 1          2  15:57:42  22/02/2024  36.5  36.8  36.0  35.8  35.4  29.4  28.9
# 2          3  15:57:49  22/02/2024  36.5  36.8  36.0  35.8  35.4  29.4  28.9
# 3          4  15:57:49  22/02/2024  36.5  36.8  36.0  35.8  35.4  29.4  28.9
# 4          5  15:57:55  22/02/2024  37.3  37.5  36.8  36.6  36.1  29.3  28.9
# ...      ...       ...         ...   ...   ...   ...   ...   ...   ...   ...
# 10648  10649  18:23:36  21/03/2024  96.0  95.4  95.7  97.3  95.5  78.6  90.8
# 10649  10650  18:23:41  21/03/2024  96.0  95.4  95.7  97.3  95.5  78.6  90.8
# 10650  10651  18:23:41  21/03/2024  96.0  95.4  95.7  97.3  95.5  78.6  90.8
# 10651  10652  18:23:43  21/03/2024  95.6  95.2  94.9  96.3  86.7  78.7  89.6
# 10652  10653  18:23:48  21/03/2024  95.6  95.2  94.9  96.3  86.7  78.7  89.6
#
#        ...  HEATER  HEATER SET POINT                date  voltage  current  \
# 0      ...      47               170 2024-02-22 15:57:40     82.1    1.216
# 1      ...      48               170 2024-02-22 15:57:42     82.1    1.216
# 2      ...      48               170 2024-02-22 15:57:49     82.1    1.216
# 3      ...      48               170 2024-02-22 15:57:49     82.1    1.215
# 4      ...      49               170 2024-02-22 15:57:55     82.1    1.215
# ...    ...     ...               ...                 ...      ...      ...
# 10648  ...     134               170 2024-03-21 18:23:36     84.1    1.235
# 10649  ...     134               170 2024-03-21 18:23:41     84.1    1.235
# 10650  ...     134               170 2024-03-21 18:23:41     84.1    1.235
# 10651  ...     134               170 2024-03-21 18:23:43     84.1    1.234
# 10652  ...     134               170 2024-03-21 18:23:48     84.0    1.234
#
#        power  Te_mean  Tc_mean    Te_std     Tc_std
# 0      100.0    36.10   28.450  0.556776   1.317826
# 1      100.0    36.10   28.450  0.556776   1.317826
# 2       99.9    36.10   28.450  0.556776   1.317826
# 3       99.7    36.10   28.450  0.556776   1.317826
# 4       99.8    36.86   28.425  0.559464   1.294540
# ...      ...      ...      ...       ...        ...
# 10648  104.0    95.98   88.650  0.772658  11.302655
# 10649  104.0    95.98   88.650  0.772658  11.302655
# 10650  104.0    95.98   88.650  0.772658  11.302655
# 10651  104.0    93.74   88.725  3.970264  10.946042
# 10652  103.8    93.74   88.400  3.970264  10.356640
#
# [10653 rows x 23 columns]

# %%
# import matplotlib.pyplot as plt
# plt.figure(figsize=(18, 10))
# for tc in df_raw_60FR_100W.columns.to_list():
#     if tc.startswith("TC_"):
#         if tc.split('_')[1] in ['6', '7', '8', '9']:
#             e = 'Condenser'
#             c = 'b'
#         else:
#             e = 'Evaporator'
#             c = 'r'
#         plt.plot(df_raw_60FR_100W['index'], df_raw_60FR_100W[tc], c=c, label=f'{e}_T[C]_{tc}')
# plt.plot(df_raw_60FR_100W['index'], df_raw_60FR_100W['Te_mean'], c='g', label='Evaporator mean [C]')
# plt.plot(df_raw_60FR_100W['index'], df_raw_60FR_100W['Tc_mean'], c='y', label='Condenser mean [C]')
# plt.fill_between(x=df_raw_60FR_100W['index'],
#                  y1=df_raw_60FR_100W['Te_mean']-df_raw_60FR_100W['Te_std'],
#                  y2=df_raw_60FR_100W['Te_mean']+df_raw_60FR_100W['Te_std'],
#                  color='r',
#                  alpha=0.2,
#                  label='Te_std')
# plt.fill_between(x=df_raw_60FR_100W['index'],
#                  y1=df_raw_60FR_100W['Tc_mean']-df_raw_60FR_100W['Tc_std'],
#                  y2=df_raw_60FR_100W['Tc_mean']+df_raw_60FR_100W['Tc_std'],
#                  color='b',
#                  alpha=0.2,
#                  label='Tc_std')
# plt.xlabel('index')
# plt.ylabel('Temperature [C]')
# plt.xlim(0,3000)
# plt.legend()

# plt.show()

# %%
# data chopping for given experiment timestamp

df_raw_60FR_100W.head()
# Out:
#        TIME        DATE  TC_1  TC_2  TC_3  TC_4  TC_5  TC_6  TC_7  TC_8  ...  \
# 1  15:57:40  22/02/2024  36.5  36.8  36.0  35.8  35.4  29.4  28.9  29.0  ...
# 2  15:57:42  22/02/2024  36.5  36.8  36.0  35.8  35.4  29.4  28.9  29.0  ...
# 3  15:57:49  22/02/2024  36.5  36.8  36.0  35.8  35.4  29.4  28.9  29.0  ...
# 4  15:57:49  22/02/2024  36.5  36.8  36.0  35.8  35.4  29.4  28.9  29.0  ...
# 5  15:57:55  22/02/2024  37.3  37.5  36.8  36.6  36.1  29.3  28.9  29.0  ...
#
#    HEATER  HEATER SET POINT                date  voltage current  power  \
# 1      47               170 2024-02-22 15:57:40     82.1   1.216  100.0
# 2      48               170 2024-02-22 15:57:42     82.1   1.216  100.0
# 3      48               170 2024-02-22 15:57:49     82.1   1.216   99.9
# 4      48               170 2024-02-22 15:57:49     82.1   1.215   99.7
# 5      49               170 2024-02-22 15:57:55     82.1   1.215   99.8
#
#    Te_mean  Tc_mean    Te_std    Tc_std
# 1    36.10   28.450  0.556776  1.317826
# 2    36.10   28.450  0.556776  1.317826
# 3    36.10   28.450  0.556776  1.317826
# 4    36.10   28.450  0.556776  1.317826
# 5    36.86   28.425  0.559464  1.294540
#
# [5 rows x 22 columns]

# %%
def load_meta_table(path:str='../data/meta_table_data.csv'):
    # csv load
    df = pd.read_csv(path)
    return df

# %%
# load meta table
df_meta_table = pd.read_csv('../data/meta_table_data.csv')
df_meta_table.drop(index=([i for i in range(10,24)]), inplace=True)
df_meta_table.fillna(0, inplace=True)

# %%
df_meta_table
# Out:
#   experiment name        Date   t_start  t_pulse_start     t_end        WF  \
# 0             php  06-04-2024  14:20:48            0.0  15:22:00  DI water
# 1             php  06-04-2024  10:25:31            0.0  11:25:00  DI water
# 2             php  06-04-2024  13:30:08            0.0  14:30:00  DI water
# 3             php  06-04-2024  16:20:59            0.0  17:20:00  DI water
# 4             php  06-04-2024  10:19:09            0.0  11:20:00  DI water
# 5             php  04-04-2024  11:32:05            0.0  12:35:00  DI water
# 6             php  03-04-2024  12:55:21            0.0  13:51:01  DI water
# 7             php  21-03-2024  14:07:55            0.0  15:34:00  DI water
# 8             php  21-03-2024  17:12:31            0.0  18:20:01  DI water
# 9             php  04-04-2024  16:32:36            0.0  17:35:00  DI water
#
#    FR [%]  Q [W]  alpha  beta
# 0    40.0   40.0   90.0   0.0
# 1    40.0   60.0   90.0   0.0
# 2    40.0   80.0   90.0   0.0
# 3    40.0  100.0   90.0   0.0
# 4    40.0  120.0   90.0   0.0
# 5    60.0   40.0   90.0   0.0
# 6    60.0   60.0   90.0   0.0
# 7    60.0   80.0   90.0   0.0
# 8    60.0  100.0   90.0   0.0
# 9    60.0  120.0   90.0   0.0

# %%
df_meta_table['dt_start'] = df_meta_table['Date'] + df_meta_table['t_start']

df_meta_table['dt_stop'] = df_meta_table['Date'] + df_meta_table['t_end']

# %%
df_meta_table['dt_start'] = pd.to_datetime(df_meta_table['dt_start'], format='%d-%m-%Y%H:%M:%S')

df_meta_table['dt_stop'] = pd.to_datetime(df_meta_table['dt_stop'], format='%d-%m-%Y%H:%M:%S')

# %%
df_meta_table
# Out:
#   experiment name        Date   t_start  t_pulse_start     t_end        WF  \
# 0             php  06-04-2024  14:20:48            0.0  15:22:00  DI water
# 1             php  06-04-2024  10:25:31            0.0  11:25:00  DI water
# 2             php  06-04-2024  13:30:08            0.0  14:30:00  DI water
# 3             php  06-04-2024  16:20:59            0.0  17:20:00  DI water
# 4             php  06-04-2024  10:19:09            0.0  11:20:00  DI water
# 5             php  04-04-2024  11:32:05            0.0  12:35:00  DI water
# 6             php  03-04-2024  12:55:21            0.0  13:51:01  DI water
# 7             php  21-03-2024  14:07:55            0.0  15:34:00  DI water
# 8             php  21-03-2024  17:12:31            0.0  18:20:01  DI water
# 9             php  04-04-2024  16:32:36            0.0  17:35:00  DI water
#
#    FR [%]  Q [W]  alpha  beta            dt_start             dt_stop
# 0    40.0   40.0   90.0   0.0 2024-04-06 14:20:48 2024-04-06 15:22:00
# 1    40.0   60.0   90.0   0.0 2024-04-06 10:25:31 2024-04-06 11:25:00
# 2    40.0   80.0   90.0   0.0 2024-04-06 13:30:08 2024-04-06 14:30:00
# 3    40.0  100.0   90.0   0.0 2024-04-06 16:20:59 2024-04-06 17:20:00
# 4    40.0  120.0   90.0   0.0 2024-04-06 10:19:09 2024-04-06 11:20:00
# 5    60.0   40.0   90.0   0.0 2024-04-04 11:32:05 2024-04-04 12:35:00
# 6    60.0   60.0   90.0   0.0 2024-04-03 12:55:21 2024-04-03 13:51:01
# 7    60.0   80.0   90.0   0.0 2024-03-21 14:07:55 2024-03-21 15:34:00
# 8    60.0  100.0   90.0   0.0 2024-03-21 17:12:31 2024-03-21 18:20:01
# 9    60.0  120.0   90.0   0.0 2024-04-04 16:32:36 2024-04-04 17:35:00

# %%
df_raw_60FR_100W.set_index('date', inplace=True)

# %%
df_meta_table
# Out:
#   experiment name        Date   t_start  t_pulse_start     t_end        WF  \
# 0             php  06-04-2024  14:20:48            0.0  15:22:00  DI water
# 1             php  06-04-2024  10:25:31            0.0  11:25:00  DI water
# 2             php  06-04-2024  13:30:08            0.0  14:30:00  DI water
# 3             php  06-04-2024  16:20:59            0.0  17:20:00  DI water
# 4             php  06-04-2024  10:19:09            0.0  11:20:00  DI water
# 5             php  04-04-2024  11:32:05            0.0  12:35:00  DI water
# 6             php  03-04-2024  12:55:21            0.0  13:51:01  DI water
# 7             php  21-03-2024  14:07:55            0.0  15:34:00  DI water
# 8             php  21-03-2024  17:12:31            0.0  18:20:01  DI water
# 9             php  04-04-2024  16:32:36            0.0  17:35:00  DI water
#
#    FR [%]  Q [W]  alpha  beta            dt_start             dt_stop
# 0    40.0   40.0   90.0   0.0 2024-04-06 14:20:48 2024-04-06 15:22:00
# 1    40.0   60.0   90.0   0.0 2024-04-06 10:25:31 2024-04-06 11:25:00
# 2    40.0   80.0   90.0   0.0 2024-04-06 13:30:08 2024-04-06 14:30:00
# 3    40.0  100.0   90.0   0.0 2024-04-06 16:20:59 2024-04-06 17:20:00
# 4    40.0  120.0   90.0   0.0 2024-04-06 10:19:09 2024-04-06 11:20:00
# 5    60.0   40.0   90.0   0.0 2024-04-04 11:32:05 2024-04-04 12:35:00
# 6    60.0   60.0   90.0   0.0 2024-04-03 12:55:21 2024-04-03 13:51:01
# 7    60.0   80.0   90.0   0.0 2024-03-21 14:07:55 2024-03-21 15:34:00
# 8    60.0  100.0   90.0   0.0 2024-03-21 17:12:31 2024-03-21 18:20:01
# 9    60.0  120.0   90.0   0.0 2024-04-04 16:32:36 2024-04-04 17:35:00

# %%
df_selected_frame = []
for index, row in df_meta_table.iterrows():
    experiment_start = row['dt_start']
    experiment_stop = row['dt_stop']
    df_sd = df_raw_60FR_100W.loc[experiment_start:experiment_stop]
    df_sd['WF'] = row['WF']
    df_sd['FR[%]'] = row['FR [%]']
    df_sd['Q[W]'] = row['Q [W]']
    df_sd['alpha'] = row['alpha']
    df_sd['beta'] = row['beta']
    df_selected_frame.append(df_sd)
    
df_data = pd.concat(df_selected_frame, ignore_index=True)
# Out:
# /var/folders/qf/2jw75py95_q8c1t5jmt77sx80000gn/T/ipykernel_26521/2975153107.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['WF'] = row['WF']
# /var/folders/qf/2jw75py95_q8c1t5jmt77sx80000gn/T/ipykernel_26521/2975153107.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['FR[%]'] = row['FR [%]']
# /var/folders/qf/2jw75py95_q8c1t5jmt77sx80000gn/T/ipykernel_26521/2975153107.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['Q[W]'] = row['Q [W]']
# /var/folders/qf/2jw75py95_q8c1t5jmt77sx80000gn/T/ipykernel_26521/2975153107.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['alpha'] = row['alpha']
# /var/folders/qf/2jw75py95_q8c1t5jmt77sx80000gn/T/ipykernel_26521/2975153107.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['beta'] = row['beta']
# /var/folders/qf/2jw75py95_q8c1t5jmt77sx80000gn/T/ipykernel_26521/2975153107.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['WF'] = row['WF']
# /var/folders/qf/2jw75py95_q8c1t5jmt77sx80000gn/T/ipykernel_26521/2975153107.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['FR[%]'] = row['FR [%]']
# /var/folders/qf/2jw75py95_q8c1t5jmt77sx80000gn/T/ipykernel_26521/2975153107.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['Q[W]'] = row['Q [W]']
# /var/folders/qf/2jw75py95_q8c1t5jmt77sx80000gn/T/ipykernel_26521/2975153107.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['alpha'] = row['alpha']
# /var/folders/qf/2jw75py95_q8c1t5jmt77sx80000gn/T/ipykernel_26521/2975153107.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['beta'] = row['beta']

# %%
df_data = process_datetime(df=df_data, col='date')

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(18, 9))
for tc in df_data.columns.to_list():
    if tc.startswith("TC_"):
        if tc.split('_')[1] in ['6', '7', '8', '9']:
            e = 'Condenser'
            c = 'o'
        else:
            e = 'Evaporator'
            c = 'x'
        plt.scatter(x=df_data['date'] ,y=df_data[tc], label=f'{e}_T[C]_{tc}', alpha=0.3, marker=c)
# Correct datetime parsing and plotting a single point
x1 = [pd.to_datetime('21-03-2024 17:20:10', format='%d-%m-%Y %H:%M:%S')]
x2 = [pd.to_datetime('21-03-2024 14:22:10', format='%d-%m-%Y %H:%M:%S')]
plt.axvline(x=x1, color='r')
plt.axvline(x=x2, color='r')
plt.xlabel('date')
plt.ylabel(f'T')
# plt.xlim(0,2600)
plt.legend()

plt.show()
