# %%
from pipelines.data_ingestion_pipe import data_ingestion_pipeline, database_generation_pipeline

# %%
# !zenml init
# !zenml stack set default

# %%
data_ingest = data_ingestion_pipeline(dir_path='../data/')
# Out:
# Initiating a new run for the pipeline: data_ingestion_pipeline.
# Reusing registered pipeline version: (version: 14).
# Executing a new run.
# Caching is disabled by default for data_ingestion_pipeline.
# Using user: default
# Using stack: default
#   artifact_store: default
#   orchestrator: default
# You can visualize your pipeline runs in the ZenML Dashboard. In order to try it locally, please run zenml up.
# Step step_initialization_DIE has started.
# No materializer is registered for type <class 'steps.data_ingestion.DataIngestionEngine'>, so the default Pickle materializer was used. Pickle is not production ready and should only be used for prototyping as the artifacts cannot be loaded when running with a different Python version. Please consider implementing a custom materializer for type <class 'steps.data_ingestion.DataIngestionEngine'> according to the instructions at https://docs.zenml.io/user-guide/advanced-guide/artifact-management/handle-custom-data-types
# Step step_initialization_DIE has finished in 0.041s.
# Step step_get_file_list has started.
# Step step_get_file_list has finished in 0.036s.
# Step step_data_ingestion has started.
# Step step_data_ingestion has finished in 0.599s.
# Step step_electrical_data_dt_process has started.
# Step step_electrical_data_dt_process has finished in 0.245s.
# Step step_thermal_data_dt_process has started.
# Step step_thermal_data_dt_process has finished in 0.248s.
# Step step_data_join has started.
# Step step_data_join has finished in 0.233s.
# Step step_cleaning_data has started.
# Step step_cleaning_data has finished in 0.426s.
# Pipeline run has finished in 2.214s.

# %%
database = database_generation_pipeline(dir_path='../data/')
# Out:
# Initiating a new run for the pipeline: database_generation_pipeline.
# Reusing registered pipeline version: (version: 2).
# Executing a new run.
# Caching is disabled by default for database_generation_pipeline.
# Using user: default
# Using stack: default
#   artifact_store: default
#   orchestrator: default
# You can visualize your pipeline runs in the ZenML Dashboard. In order to try it locally, please run zenml up.
# Step step_initialize_DPE has started.
# No materializer is registered for type <class 'steps.data_selection.DataProcessingEngine'>, so the default Pickle materializer was used. Pickle is not production ready and should only be used for prototyping as the artifacts cannot be loaded when running with a different Python version. Please consider implementing a custom materializer for type <class 'steps.data_selection.DataProcessingEngine'> according to the instructions at https://docs.zenml.io/user-guide/advanced-guide/artifact-management/handle-custom-data-types
# Step step_initialize_DPE has finished in 0.030s.
# Step step_loading_meta_table has started.
# Step step_loading_meta_table has finished in 0.165s.
# Step step_meta_data_dt_process has started.
# Step step_meta_data_dt_process has finished in 0.285s.
# Step step_database has started.
# /Users/nirmal/Documents/np_dsci_codes/Advanced_PulseHeatPipe/ml/steps/data_selection.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['WF'] = row['WF']
# /Users/nirmal/Documents/np_dsci_codes/Advanced_PulseHeatPipe/ml/steps/data_selection.py:100: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['FR[%]'] = row['FR [%]']
# /Users/nirmal/Documents/np_dsci_codes/Advanced_PulseHeatPipe/ml/steps/data_selection.py:101: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['Q[W]'] = row['Q [W]']
# /Users/nirmal/Documents/np_dsci_codes/Advanced_PulseHeatPipe/ml/steps/data_selection.py:102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['alpha'] = row['alpha']
# /Users/nirmal/Documents/np_dsci_codes/Advanced_PulseHeatPipe/ml/steps/data_selection.py:103: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['beta'] = row['beta']
# /Users/nirmal/Documents/np_dsci_codes/Advanced_PulseHeatPipe/ml/steps/data_selection.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['WF'] = row['WF']
# /Users/nirmal/Documents/np_dsci_codes/Advanced_PulseHeatPipe/ml/steps/data_selection.py:100: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['FR[%]'] = row['FR [%]']
# /Users/nirmal/Documents/np_dsci_codes/Advanced_PulseHeatPipe/ml/steps/data_selection.py:101: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['Q[W]'] = row['Q [W]']
# /Users/nirmal/Documents/np_dsci_codes/Advanced_PulseHeatPipe/ml/steps/data_selection.py:102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['alpha'] = row['alpha']
# /Users/nirmal/Documents/np_dsci_codes/Advanced_PulseHeatPipe/ml/steps/data_selection.py:103: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['beta'] = row['beta']
# /Users/nirmal/Documents/np_dsci_codes/Advanced_PulseHeatPipe/ml/steps/data_selection.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['WF'] = row['WF']
# /Users/nirmal/Documents/np_dsci_codes/Advanced_PulseHeatPipe/ml/steps/data_selection.py:100: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['FR[%]'] = row['FR [%]']
# /Users/nirmal/Documents/np_dsci_codes/Advanced_PulseHeatPipe/ml/steps/data_selection.py:101: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['Q[W]'] = row['Q [W]']
# /Users/nirmal/Documents/np_dsci_codes/Advanced_PulseHeatPipe/ml/steps/data_selection.py:102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['alpha'] = row['alpha']
# /Users/nirmal/Documents/np_dsci_codes/Advanced_PulseHeatPipe/ml/steps/data_selection.py:103: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['beta'] = row['beta']
# /Users/nirmal/Documents/np_dsci_codes/Advanced_PulseHeatPipe/ml/steps/data_selection.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['WF'] = row['WF']
# /Users/nirmal/Documents/np_dsci_codes/Advanced_PulseHeatPipe/ml/steps/data_selection.py:100: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['FR[%]'] = row['FR [%]']
# /Users/nirmal/Documents/np_dsci_codes/Advanced_PulseHeatPipe/ml/steps/data_selection.py:101: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['Q[W]'] = row['Q [W]']
# /Users/nirmal/Documents/np_dsci_codes/Advanced_PulseHeatPipe/ml/steps/data_selection.py:102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['alpha'] = row['alpha']
# /Users/nirmal/Documents/np_dsci_codes/Advanced_PulseHeatPipe/ml/steps/data_selection.py:103: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['beta'] = row['beta']
# /Users/nirmal/Documents/np_dsci_codes/Advanced_PulseHeatPipe/ml/steps/data_selection.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['WF'] = row['WF']
# /Users/nirmal/Documents/np_dsci_codes/Advanced_PulseHeatPipe/ml/steps/data_selection.py:100: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['FR[%]'] = row['FR [%]']
# /Users/nirmal/Documents/np_dsci_codes/Advanced_PulseHeatPipe/ml/steps/data_selection.py:101: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['Q[W]'] = row['Q [W]']
# /Users/nirmal/Documents/np_dsci_codes/Advanced_PulseHeatPipe/ml/steps/data_selection.py:102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['alpha'] = row['alpha']
# /Users/nirmal/Documents/np_dsci_codes/Advanced_PulseHeatPipe/ml/steps/data_selection.py:103: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['beta'] = row['beta']
# /Users/nirmal/Documents/np_dsci_codes/Advanced_PulseHeatPipe/ml/steps/data_selection.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['WF'] = row['WF']
# /Users/nirmal/Documents/np_dsci_codes/Advanced_PulseHeatPipe/ml/steps/data_selection.py:100: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['FR[%]'] = row['FR [%]']
# /Users/nirmal/Documents/np_dsci_codes/Advanced_PulseHeatPipe/ml/steps/data_selection.py:101: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['Q[W]'] = row['Q [W]']
# /Users/nirmal/Documents/np_dsci_codes/Advanced_PulseHeatPipe/ml/steps/data_selection.py:102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['alpha'] = row['alpha']
# /Users/nirmal/Documents/np_dsci_codes/Advanced_PulseHeatPipe/ml/steps/data_selection.py:103: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['beta'] = row['beta']
# /Users/nirmal/Documents/np_dsci_codes/Advanced_PulseHeatPipe/ml/steps/data_selection.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['WF'] = row['WF']
# /Users/nirmal/Documents/np_dsci_codes/Advanced_PulseHeatPipe/ml/steps/data_selection.py:100: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['FR[%]'] = row['FR [%]']
# /Users/nirmal/Documents/np_dsci_codes/Advanced_PulseHeatPipe/ml/steps/data_selection.py:101: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['Q[W]'] = row['Q [W]']
# /Users/nirmal/Documents/np_dsci_codes/Advanced_PulseHeatPipe/ml/steps/data_selection.py:102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['alpha'] = row['alpha']
# /Users/nirmal/Documents/np_dsci_codes/Advanced_PulseHeatPipe/ml/steps/data_selection.py:103: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['beta'] = row['beta']
# Step step_database has finished in 0.444s.
# Pipeline run has finished in 1.060s.
