# %%
from pipelines.data_ingestion_pipe import data_ingestion_pipeline, database_generation_pipeline

# %%
# !zenml init
# !zenml stack set default

# %%
data_ingest = data_ingestion_pipeline(dir_path='../data/')
# Out:
# Initiating a new run for the pipeline: data_ingestion_pipeline.
# Reusing registered pipeline version: (version: 14).
# Executing a new run.
# Caching is disabled by default for data_ingestion_pipeline.
# Using user: default
# Using stack: default
#   artifact_store: default
#   orchestrator: default
# You can visualize your pipeline runs in the ZenML Dashboard. In order to try it locally, please run zenml up.
# Step step_initialization_DIE has started.
# No materializer is registered for type <class 'steps.data_ingestion.DataIngestionEngine'>, so the default Pickle materializer was used. Pickle is not production ready and should only be used for prototyping as the artifacts cannot be loaded when running with a different Python version. Please consider implementing a custom materializer for type <class 'steps.data_ingestion.DataIngestionEngine'> according to the instructions at https://docs.zenml.io/user-guide/advanced-guide/artifact-management/handle-custom-data-types
# Step step_initialization_DIE has finished in 0.072s.
# Step step_get_file_list has started.
# Step step_get_file_list has finished in 0.035s.
# Step step_data_ingestion has started.
# Step step_data_ingestion has finished in 0.687s.
# Step step_electrical_data_dt_process has started.
# Step step_electrical_data_dt_process has finished in 0.409s.
# Step step_thermal_data_dt_process has started.
# Step step_thermal_data_dt_process has finished in 0.288s.
# Step step_data_join has started.
# Step step_data_join has finished in 0.309s.
# Step step_cleaning_data has started.
# Step step_cleaning_data has finished in 0.609s.
# Pipeline run has finished in 2.999s.

# %%
database = database_generation_pipeline(dir_path='../data/')
# Out:
# Initiating a new run for the pipeline: database_generation_pipeline.
# Registered new version: (version 5).
# Executing a new run.
# Caching is disabled by default for database_generation_pipeline.
# Using user: default
# Using stack: default
#   artifact_store: default
#   orchestrator: default
# You can visualize your pipeline runs in the ZenML Dashboard. In order to try it locally, please run zenml up.
# Step step_initialize_DPE has started.
# No materializer is registered for type <class 'steps.data_processing.DataProcessingEngine'>, so the default Pickle materializer was used. Pickle is not production ready and should only be used for prototyping as the artifacts cannot be loaded when running with a different Python version. Please consider implementing a custom materializer for type <class 'steps.data_processing.DataProcessingEngine'> according to the instructions at https://docs.zenml.io/user-guide/advanced-guide/artifact-management/handle-custom-data-types
# Step step_initialize_DPE has finished in 0.041s.
# Step step_loading_meta_table has started.
# Step step_loading_meta_table has finished in 0.202s.
# Step step_meta_data_dt_process has started.
# Step step_meta_data_dt_process has finished in 0.197s.
# Step step_database has started.
# /Users/nirmal/Documents/np_dsci_codes/Advanced_PulseHeatPipe/ml/steps/data_processing.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['WF'] = row['WF']
# /Users/nirmal/Documents/np_dsci_codes/Advanced_PulseHeatPipe/ml/steps/data_processing.py:100: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['FR[%]'] = row['FR [%]']
# /Users/nirmal/Documents/np_dsci_codes/Advanced_PulseHeatPipe/ml/steps/data_processing.py:101: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['Q[W]'] = row['Q [W]']
# /Users/nirmal/Documents/np_dsci_codes/Advanced_PulseHeatPipe/ml/steps/data_processing.py:102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['alpha'] = row['alpha']
# /Users/nirmal/Documents/np_dsci_codes/Advanced_PulseHeatPipe/ml/steps/data_processing.py:103: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['beta'] = row['beta']
# /Users/nirmal/Documents/np_dsci_codes/Advanced_PulseHeatPipe/ml/steps/data_processing.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['WF'] = row['WF']
# /Users/nirmal/Documents/np_dsci_codes/Advanced_PulseHeatPipe/ml/steps/data_processing.py:100: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['FR[%]'] = row['FR [%]']
# /Users/nirmal/Documents/np_dsci_codes/Advanced_PulseHeatPipe/ml/steps/data_processing.py:101: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['Q[W]'] = row['Q [W]']
# /Users/nirmal/Documents/np_dsci_codes/Advanced_PulseHeatPipe/ml/steps/data_processing.py:102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['alpha'] = row['alpha']
# /Users/nirmal/Documents/np_dsci_codes/Advanced_PulseHeatPipe/ml/steps/data_processing.py:103: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['beta'] = row['beta']
# /Users/nirmal/Documents/np_dsci_codes/Advanced_PulseHeatPipe/ml/steps/data_processing.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['WF'] = row['WF']
# /Users/nirmal/Documents/np_dsci_codes/Advanced_PulseHeatPipe/ml/steps/data_processing.py:100: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['FR[%]'] = row['FR [%]']
# /Users/nirmal/Documents/np_dsci_codes/Advanced_PulseHeatPipe/ml/steps/data_processing.py:101: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['Q[W]'] = row['Q [W]']
# /Users/nirmal/Documents/np_dsci_codes/Advanced_PulseHeatPipe/ml/steps/data_processing.py:102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['alpha'] = row['alpha']
# /Users/nirmal/Documents/np_dsci_codes/Advanced_PulseHeatPipe/ml/steps/data_processing.py:103: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['beta'] = row['beta']
# /Users/nirmal/Documents/np_dsci_codes/Advanced_PulseHeatPipe/ml/steps/data_processing.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['WF'] = row['WF']
# /Users/nirmal/Documents/np_dsci_codes/Advanced_PulseHeatPipe/ml/steps/data_processing.py:100: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['FR[%]'] = row['FR [%]']
# /Users/nirmal/Documents/np_dsci_codes/Advanced_PulseHeatPipe/ml/steps/data_processing.py:101: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['Q[W]'] = row['Q [W]']
# /Users/nirmal/Documents/np_dsci_codes/Advanced_PulseHeatPipe/ml/steps/data_processing.py:102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['alpha'] = row['alpha']
# /Users/nirmal/Documents/np_dsci_codes/Advanced_PulseHeatPipe/ml/steps/data_processing.py:103: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['beta'] = row['beta']
# /Users/nirmal/Documents/np_dsci_codes/Advanced_PulseHeatPipe/ml/steps/data_processing.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['WF'] = row['WF']
# /Users/nirmal/Documents/np_dsci_codes/Advanced_PulseHeatPipe/ml/steps/data_processing.py:100: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['FR[%]'] = row['FR [%]']
# /Users/nirmal/Documents/np_dsci_codes/Advanced_PulseHeatPipe/ml/steps/data_processing.py:101: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['Q[W]'] = row['Q [W]']
# /Users/nirmal/Documents/np_dsci_codes/Advanced_PulseHeatPipe/ml/steps/data_processing.py:102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['alpha'] = row['alpha']
# /Users/nirmal/Documents/np_dsci_codes/Advanced_PulseHeatPipe/ml/steps/data_processing.py:103: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['beta'] = row['beta']
# /Users/nirmal/Documents/np_dsci_codes/Advanced_PulseHeatPipe/ml/steps/data_processing.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['WF'] = row['WF']
# /Users/nirmal/Documents/np_dsci_codes/Advanced_PulseHeatPipe/ml/steps/data_processing.py:100: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['FR[%]'] = row['FR [%]']
# /Users/nirmal/Documents/np_dsci_codes/Advanced_PulseHeatPipe/ml/steps/data_processing.py:101: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['Q[W]'] = row['Q [W]']
# /Users/nirmal/Documents/np_dsci_codes/Advanced_PulseHeatPipe/ml/steps/data_processing.py:102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['alpha'] = row['alpha']
# /Users/nirmal/Documents/np_dsci_codes/Advanced_PulseHeatPipe/ml/steps/data_processing.py:103: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['beta'] = row['beta']
# /Users/nirmal/Documents/np_dsci_codes/Advanced_PulseHeatPipe/ml/steps/data_processing.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['WF'] = row['WF']
# /Users/nirmal/Documents/np_dsci_codes/Advanced_PulseHeatPipe/ml/steps/data_processing.py:100: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['FR[%]'] = row['FR [%]']
# /Users/nirmal/Documents/np_dsci_codes/Advanced_PulseHeatPipe/ml/steps/data_processing.py:101: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['Q[W]'] = row['Q [W]']
# /Users/nirmal/Documents/np_dsci_codes/Advanced_PulseHeatPipe/ml/steps/data_processing.py:102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['alpha'] = row['alpha']
# /Users/nirmal/Documents/np_dsci_codes/Advanced_PulseHeatPipe/ml/steps/data_processing.py:103: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sd['beta'] = row['beta']
# Step step_database has finished in 0.440s.
# Step step_stat_cols has started.
# Step step_stat_cols has finished in 0.359s.
# Step step_database_csv has started.
# Step step_database_csv has finished in 0.279s.
# Pipeline run has finished in 1.840s.

# %%
from zenml.client import Client

artifact = Client().get_artifact_version('8277640f-874c-4db6-a0c9-86fac7db0453')
df = artifact.load()


df
# Out:
#            TIME        DATE  TC_1  TC_2  TC_3  TC_4  TC_5  TC_6  TC_7  TC_8  \
# 0      11:02:34  06/04/2024  32.7  33.0  32.3  32.3  32.7  33.1  32.8  32.8
# 1      11:02:35  06/04/2024  32.7  33.0  32.3  32.3  32.7  33.1  32.8  32.8
# 2      11:02:38  06/04/2024  32.7  33.0  32.3  32.3  32.7  33.1  32.8  32.8
# 3      11:02:39  06/04/2024  32.7  33.0  32.3  32.3  32.7  33.1  32.8  32.8
# 4      11:02:40  06/04/2024  32.7  33.0  32.3  32.3  32.7  33.1  32.8  32.8
# ...         ...         ...   ...   ...   ...   ...   ...   ...   ...   ...
# 11757  17:34:50  04/04/2024  94.4  96.2  96.7  98.2  98.2  73.8  92.2  93.1
# 11758  17:34:52  04/04/2024  94.4  96.2  96.7  98.2  98.2  73.8  92.2  89.4
# 11759  17:34:53  04/04/2024  94.5  96.3  97.0  98.5  98.2  73.8  92.2  89.4
# 11760  17:34:55  04/04/2024  94.5  96.3  97.0  98.5  97.9  74.1  92.5  88.9
# 11761  17:34:59  04/04/2024  94.5  96.3  97.0  98.5  97.9  74.1  92.5  88.9
#
#        ...  power        WF  FR[%]   Q[W]  alpha  beta  Te_mean[C] Tc_mean[C]  \
# 0      ...    0.0  DI water   40.0   60.0   90.0   0.0       32.60     32.225
# 1      ...    0.0  DI water   40.0   60.0   90.0   0.0       32.60     32.225
# 2      ...  114.3  DI water   40.0   60.0   90.0   0.0       32.60     32.225
# 3      ...  114.3  DI water   40.0   60.0   90.0   0.0       32.60     32.225
# 4      ...  102.0  DI water   40.0   60.0   90.0   0.0       32.60     32.225
# ...    ...    ...       ...    ...    ...    ...   ...         ...        ...
# 11757  ...  120.2  DI water   60.0  120.0   90.0   0.0       96.74     90.400
# 11758  ...  120.1  DI water   60.0  120.0   90.0   0.0       96.74     89.525
# 11759  ...  120.2  DI water   60.0  120.0   90.0   0.0       96.90     89.525
# 11760  ...  120.2  DI water   60.0  120.0   90.0   0.0       96.84     89.550
# 11761  ...  120.1  DI water   60.0  120.0   90.0   0.0       96.84     89.425
#
#        Te_std[C]  Tc_std[C]
# 0       0.300000   1.357387
# 1       0.300000   1.357387
# 2       0.300000   1.357387
# 3       0.300000   1.357387
# 4       0.300000   1.357387
# ...          ...        ...
# 11757   1.583667  12.006942
# 11758   1.583667  11.944699
# 11759   1.610900  11.944699
# 11760   1.554992  11.842719
# 11761   1.554992  11.658866
#
# [11762 rows x 26 columns]

# %%
frs = df['FR[%]'].unique()
qs = df['Q[W]'].unique()
alphas = df['alpha'].unique()
betas = df['beta'].unique()
betas
# Out:
# array([0.])

# %%
import matplotlib.pyplot as plt

# Assuming frs, qs, alphas, betas are defined and df is your DataFrame
plt.figure(figsize=(18, 9))
for fr in frs:
    print(f'FR {fr}')
    for q in qs:
        print(f'Q {q}')
        for a in alphas:
            for b in betas:
                print(f'alpha {a}, beta {b}')
                
                # Filter the dataframe
                df_ = df[(df['FR[%]'] == fr) & (df['Q[W]'] == q) & (df['alpha'] == a) & (df['beta'] == b)]
                
                if not df_.empty:
                    # Plotting
                    # plt.figure(figsize=(18, 6))
                    plt.plot(df_['Te_mean[C]'], label=f'FR{fr}[%]_Q{q}[W]_A[{a}]_B[{b}]_Te_mean[C]')
                    plt.plot(df_['Tc_mean[C]'], label=f'FR{fr}[%]_Q{q}[W]_A[{a}]_B[{b}]_Tc_mean[C]')
plt.legend()
plt.title(f'FR {fr}% - Q {q}W - alpha {a} - beta {b}')
plt.show()
# Out:
# FR 40.0
# Q 60.0
# alpha 90.0, beta 0.0
# Q 120.0
# alpha 90.0, beta 0.0
# Q 40.0
# alpha 90.0, beta 0.0
# Q 80.0
# alpha 90.0, beta 0.0
# Q 100.0
# alpha 90.0, beta 0.0
# FR 60.0
# Q 60.0
# alpha 90.0, beta 0.0
# Q 120.0
# alpha 90.0, beta 0.0
# Q 40.0
# alpha 90.0, beta 0.0
# Q 80.0
# alpha 90.0, beta 0.0
# Q 100.0
# alpha 90.0, beta 0.0

# %%
import matplotlib.pyplot as plt

# Assuming frs, qs, alphas, betas are defined and df is your DataFrame
plt.figure(figsize=(18, 9))
for fr in frs:
    print(f'FR {fr}')
    for q in qs:
        print(f'Q {q}')
        for a in alphas:
            for b in betas:
                print(f'alpha {a}, beta {b}')
                
                # Filter the dataframe
                df_ = df[(df['FR[%]'] == fr) & (df['Q[W]'] == q) & (df['alpha'] == a) & (df['beta'] == b)]
                
                if not df_.empty:
                    # Plotting
                    plt.figure(figsize=(18, 6))
                    plt.plot(df_['Te_mean[C]'], label=f'FR{fr}[%]_Q{q}[W]_A[{a}]_B[{b}]_Te_mean[C]')
                    plt.plot(df_['Tc_mean[C]'], label=f'FR{fr}[%]_Q{q}[W]_A[{a}]_B[{b}]_Tc_mean[C]')
                    plt.legend()
                    plt.title(f'FR {fr}% - Q {q}W - alpha {a} - beta {b}')
                    plt.show()
